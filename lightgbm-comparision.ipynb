# %% [markdown]
# # **High Performance Machine Learning**
# ### Demo of Hummingbird and Treelite

# %% [markdown]
# ### Install external libraries
# First we will install the hummingbird libraries together with ONNX runtime libraries.
# Next we will setup the treelite libraries. We want to make sure envoirnment contains them.

# %%
# !pip install --user hummingbird_ml[extra,onnx]
# !pip install --user treelite treelite_runtime
# Out:
# Collecting hummingbird_ml[extra,onnx]
#   Downloading hummingbird_ml-0.0.6-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 354 kB/s eta 0:00:011
# Collecting onnxconverter-common>=1.6.0
#   Downloading onnxconverter_common-1.7.0-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.1 MB/s eta 0:00:011
# Requirement already satisfied: torch>=1.4.* in /opt/conda/lib/python3.7/site-packages (from hummingbird_ml[extra,onnx]) (1.6.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from hummingbird_ml[extra,onnx]) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/conda/lib/python3.7/site-packages (from hummingbird_ml[extra,onnx]) (0.23.2)
# Requirement already satisfied: xgboost>=0.90; extra == "extra" in /opt/conda/lib/python3.7/site-packages (from hummingbird_ml[extra,onnx]) (1.2.0)
# Requirement already satisfied: lightgbm<3,>=2.2; extra == "extra" in /opt/conda/lib/python3.7/site-packages (from hummingbird_ml[extra,onnx]) (2.3.1)
# Collecting onnxruntime>=1.0.0; extra == "onnx"
#   Downloading onnxruntime-1.5.1-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 3.4 MB/s eta 0:00:01
# Collecting onnxmltools>=1.6.0; extra == "onnx"
#   Downloading onnxmltools-1.7.0-py2.py3-none-any.whl (252 kB)
#      |████████████████████████████████| 252 kB 9.6 MB/s eta 0:00:01
# Requirement already satisfied: onnx in /opt/conda/lib/python3.7/site-packages (from onnxconverter-common>=1.6.0->hummingbird_ml[extra,onnx]) (1.7.0)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.7/site-packages (from onnxconverter-common>=1.6.0->hummingbird_ml[extra,onnx]) (3.13.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.4.*->hummingbird_ml[extra,onnx]) (0.18.2)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.21.3->hummingbird_ml[extra,onnx]) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.21.3->hummingbird_ml[extra,onnx]) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.21.3->hummingbird_ml[extra,onnx]) (2.1.0)
# Collecting keras2onnx
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.5 MB/s  eta 0:00:01
# Collecting skl2onnx
#   Downloading skl2onnx-1.7.0-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 9.6 MB/s eta 0:00:01
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from onnx->onnxconverter-common>=1.6.0->hummingbird_ml[extra,onnx]) (1.14.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/conda/lib/python3.7/site-packages (from onnx->onnxconverter-common>=1.6.0->hummingbird_ml[extra,onnx]) (3.7.4.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf->onnxconverter-common>=1.6.0->hummingbird_ml[extra,onnx]) (46.1.3.post20200325)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (2.23.0)
# Collecting fire
#   Downloading fire-0.3.1.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 4.3 MB/s eta 0:00:011
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (1.24.3)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.7/site-packages (from fire->keras2onnx->onnxmltools>=1.6.0; extra == "onnx"->hummingbird_ml[extra,onnx]) (1.1.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.3.1-py2.py3-none-any.whl size=111005 sha256=7ce244b89610074ac3ebbb6434437f40411979e829fa9133868a0ce0720fd0a3
#   Stored in directory: /root/.cache/pip/wheels/95/38/e1/8b62337a8ecf5728bdc1017e828f253f7a9cf25db999861bec
# Successfully built fire
# Installing collected packages: onnxconverter-common, onnxruntime, fire, keras2onnx, skl2onnx, onnxmltools, hummingbird-ml
#   WARNING: The script onnxruntime_test is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed fire-0.3.1 hummingbird-ml-0.0.6 keras2onnx-1.7.0 onnxconverter-common-1.7.0 onnxmltools-1.7.0 onnxruntime-1.5.1 skl2onnx-1.7.0
# Collecting treelite
#   Downloading treelite-0.93-py3-none-manylinux2010_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 402 kB/s eta 0:00:01
# Collecting treelite_runtime
#   Downloading treelite_runtime-0.93-py3-none-manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from treelite) (1.18.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from treelite) (1.4.1)
# Installing collected packages: treelite, treelite-runtime
# Successfully installed treelite-0.93 treelite-runtime-0.93

# %%
# Default import to run the codes
import torch

import numpy as np

#Gradient Boosted Tree libraries (XGBoost, LightGBM)
import xgboost as xgb
import lightgbm as lgb

#Treelite Imports
import treelite
import treelite_runtime     # runtime module

#Onnx Runtime libraries
import onnxruntime as ort
from onnxmltools.convert import convert_lightgbm
from onnxconverter_common.data_types import FloatTensorType

#Hummingbird libraries
from hummingbird.ml import convert
from hummingbird.ml import constants

# To measure the run speeds
from timeit import Timer

# %% [markdown]
# We will start by generating some random dataset for binary classification, before moving on to real life datasets.
# This is to demonstrate the capabilties of various libaries that allows for comparison among various approaches.
# Do note that we are working through Numpy arrays as compared to Pandas Dataframes that you will encounter in real life.

# %%
# Create some random data for binary classification.
num_classes = 2
X = np.array(np.random.rand(10000, 28), dtype=np.float32)
y = np.random.randint(num_classes, size=10000)

# %% [markdown]
# Create a function that will repeat the functions a few time to get an accurate measures

# %%
def speed(inst, number=5, repeat=2):
    timer = Timer(inst, globals=globals())
    raw = np.array(timer.repeat(repeat, number=number))
    ave = raw.sum() / len(raw) / number
    mi, ma = raw.min() / number, raw.max() / number
    print("Average %1.3g Min=%1.3g Max=%1.3g" % (ave, mi, ma))
    return ave

# %% [markdown]
# ### Create and train a model starting with LightGBM

# %%
model = lgb.LGBMClassifier()
model.fit(X, y)
# Out:
# LGBMClassifier()

# %%
# Use ONNXMLTOOLS to convert the model to ONNXML.
# You can adjust the inputs to suit you need, where the model will do batch or real-time inference. 
# The same of the file can determine the shape, you will see this later on. 
initial_types = [("input", FloatTensorType([X.shape[0], X.shape[1]]))] # Define the inputs for the ONNX

#ONNX Model 
onnx_ml_model = convert_lightgbm(
    model, initial_types=initial_types, target_opset=9
)

# %% [markdown]
# The Onnx Model
# ![../input/lgbmonnx/lgbm_onnx.onnx.png](../input/lgbmonnx/lgbm_onnx.onnx.png[](http://))

# %%
onnx_ml_model
# Out:
# ir_version: 4
# producer_name: "OnnxMLTools"
# producer_version: "1.7.0"
# domain: "onnxconverter-common"
# model_version: 0
# doc_string: ""
# graph {
#   node {
#     input: "input"
#     output: "label_tensor"
#     output: "probability_tensor"
#     name: "LgbmClassifier"
#     op_type: "TreeEnsembleClassifier"
#     attribute {
#       name: "class_ids"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "class_nodeids"
#       ints: 7
#       ints: 11
#       ints: 12
#       ints: 10
#       ints: 13
#       ints: 15
#       ints: 16
#       ints: 17
#       ints: 23
#       ints: 24
#       ints: 25
#       ints: 26
#       ints: 33
#       ints: 34
#       ints: 32
#       ints: 37
#       ints: 38
#       ints: 39
#       ints: 40
#       ints: 28
#       ints: 43
#       ints: 44
#       ints: 47
#       ints: 51
#       ints: 52
#       ints: 59
#       ints: 60
#       ints: 58
#       ints: 56
#       ints: 54
#       ints: 46
#       ints: 7
#       ints: 9
#       ints: 13
#       ints: 14
#       ints: 12
#       ints: 17
#       ints: 18
#       ints: 16
#       ints: 19
#       ints: 23
#       ints: 24
#       ints: 27
#       ints: 28
#       ints: 26
#       ints: 37
#       ints: 38
#       ints: 36
#       ints: 39
#       ints: 40
#       ints: 32
#       ints: 47
#       ints: 48
#       ints: 46
#       ints: 53
#       ints: 54
#       ints: 52
#       ints: 55
#       ints: 56
#       ints: 59
#       ints: 60
#       ints: 58
#       ints: 13
#       ints: 14
#       ints: 17
#       ints: 18
#       ints: 21
#       ints: 22
#       ints: 23
#       ints: 24
#       ints: 25
#       ints: 26
#       ints: 31
#       ints: 33
#       ints: 37
#       ints: 38
#       ints: 39
#       ints: 40
#       ints: 30
#       ints: 41
#       ints: 42
#       ints: 45
#       ints: 49
#       ints: 50
#       ints: 53
#       ints: 54
#       ints: 52
#       ints: 55
#       ints: 57
#       ints: 58
#       ints: 4
#       ints: 59
#       ints: 60
#       ints: 3
#       ints: 13
#       ints: 14
#       ints: 12
#       ints: 10
#       ints: 15
#       ints: 16
#       ints: 6
#       ints: 17
#       ints: 25
#       ints: 26
#       ints: 27
#       ints: 29
#       ints: 30
#       ints: 31
#       ints: 35
#       ints: 39
#       ints: 40
#       ints: 38
#       ints: 43
#       ints: 45
#       ints: 46
#       ints: 47
#       ints: 48
#       ints: 51
#       ints: 52
#       ints: 55
#       ints: 56
#       ints: 59
#       ints: 60
#       ints: 58
#       ints: 5
#       ints: 9
#       ints: 10
#       ints: 17
#       ints: 18
#       ints: 19
#       ints: 20
#       ints: 21
#       ints: 23
#       ints: 24
#       ints: 29
#       ints: 30
#       ints: 28
#       ints: 26
#       ints: 31
#       ints: 41
#       ints: 42
#       ints: 40
#       ints: 43
#       ints: 44
#       ints: 45
#       ints: 46
#       ints: 53
#       ints: 54
#       ints: 52
#       ints: 50
#       ints: 55
#       ints: 59
#       ints: 60
#       ints: 58
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 7
#       ints: 19
#       ints: 20
#       ints: 18
#       ints: 16
#       ints: 21
#       ints: 22
#       ints: 12
#       ints: 10
#       ints: 27
#       ints: 31
#       ints: 32
#       ints: 33
#       ints: 37
#       ints: 41
#       ints: 42
#       ints: 40
#       ints: 43
#       ints: 49
#       ints: 50
#       ints: 53
#       ints: 54
#       ints: 55
#       ints: 57
#       ints: 58
#       ints: 46
#       ints: 59
#       ints: 60
#       ints: 24
#       ints: 5
#       ints: 6
#       ints: 13
#       ints: 15
#       ints: 17
#       ints: 19
#       ints: 21
#       ints: 22
#       ints: 23
#       ints: 25
#       ints: 27
#       ints: 28
#       ints: 35
#       ints: 39
#       ints: 40
#       ints: 41
#       ints: 42
#       ints: 43
#       ints: 45
#       ints: 47
#       ints: 48
#       ints: 51
#       ints: 52
#       ints: 50
#       ints: 55
#       ints: 56
#       ints: 54
#       ints: 8
#       ints: 57
#       ints: 59
#       ints: 60
#       ints: 1
#       ints: 3
#       ints: 11
#       ints: 13
#       ints: 14
#       ints: 10
#       ints: 8
#       ints: 23
#       ints: 27
#       ints: 28
#       ints: 26
#       ints: 29
#       ints: 35
#       ints: 37
#       ints: 39
#       ints: 40
#       ints: 34
#       ints: 32
#       ints: 43
#       ints: 49
#       ints: 50
#       ints: 48
#       ints: 46
#       ints: 42
#       ints: 51
#       ints: 53
#       ints: 54
#       ints: 57
#       ints: 58
#       ints: 59
#       ints: 60
#       ints: 7
#       ints: 9
#       ints: 10
#       ints: 17
#       ints: 19
#       ints: 20
#       ints: 21
#       ints: 22
#       ints: 25
#       ints: 31
#       ints: 32
#       ints: 30
#       ints: 33
#       ints: 34
#       ints: 35
#       ints: 36
#       ints: 41
#       ints: 42
#       ints: 43
#       ints: 47
#       ints: 48
#       ints: 49
#       ints: 53
#       ints: 54
#       ints: 52
#       ints: 55
#       ints: 57
#       ints: 58
#       ints: 4
#       ints: 59
#       ints: 60
#       ints: 5
#       ints: 6
# ...
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.08743859082460403
#       floats: 0.13777165114879608
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9046648144721985
#       floats: 0.5548874139785767
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9365719556808472
#       floats: 0.4482882618904114
#       floats: 0.0
#       floats: 0.0
#       floats: 0.09487774223089218
#       floats: 0.0
#       floats: 0.0
#       floats: 0.426726371049881
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9794107675552368
#       floats: 0.0047544757835567
#       floats: 0.823777437210083
#       floats: 0.0
#       floats: 0.01605374738574028
#       floats: 0.840095043182373
#       floats: 0.025217195972800255
#       floats: 0.427710622549057
#       floats: 0.0
#       floats: 0.531602680683136
#       floats: 0.6618395447731018
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.4765545725822449
#       floats: 0.8817091584205627
#       floats: 0.5902422666549683
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5092370510101318
#       floats: 0.07685549557209015
#       floats: 0.6057866215705872
#       floats: 0.0
#       floats: 0.47016236186027527
#       floats: 0.0
#       floats: 0.10985279083251953
#       floats: 0.0
#       floats: 0.39783114194869995
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8104760050773621
#       floats: 0.11523624509572983
#       floats: 0.5513519644737244
#       floats: 0.6174759864807129
#       floats: 0.8971753716468811
#       floats: 0.0
#       floats: 0.20269307494163513
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3529520332813263
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3947697877883911
#       floats: 0.0
#       floats: 0.3431468605995178
#       floats: 0.7854768633842468
#       floats: 0.0
#       floats: 0.0
#       floats: 0.4030872881412506
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6877714991569519
#       floats: 0.0
#       floats: 0.0
#       floats: 0.07695402204990387
#       floats: 0.3245765268802643
#       floats: 0.09405848383903503
#       floats: 0.146724671125412
#       floats: 0.8787737488746643
#       floats: 0.0
#       floats: 0.14078761637210846
#       floats: 0.0
#       floats: 0.6949756145477295
#       floats: 0.16764356195926666
#       floats: 0.0
#       floats: 0.0
#       floats: 0.227760449051857
#       floats: 0.0
#       floats: 0.17153367400169373
#       floats: 0.0
#       floats: 0.44003811478614807
#       floats: 0.0
#       floats: 0.0
#       floats: 0.1695212572813034
#       floats: 0.5668638348579407
#       floats: 0.301286906003952
#       floats: 0.9511129856109619
#       floats: 0.0
#       floats: 0.7018740773200989
#       floats: 0.0
#       floats: 0.0
#       floats: 0.23097211122512817
#       floats: 0.0
#       floats: 0.0
#       floats: 0.13920672237873077
#       floats: 0.4569629728794098
#       floats: 0.41384780406951904
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.42160072922706604
#       floats: 0.2942575216293335
#       floats: 0.3645886182785034
#       floats: 0.41495200991630554
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5162516236305237
#       floats: 0.0
#       floats: 0.5632330179214478
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5293437838554382
#       floats: 0.0
#       floats: 0.5628982186317444
#       floats: 0.6698484420776367
#       floats: 0.0
#       floats: 0.0
#       floats: 0.2851064205169678
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9958127737045288
#       floats: 0.9924660325050354
#       floats: 0.0
#       floats: 0.005285906605422497
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8159149885177612
#       floats: 0.0
#       floats: 0.8380132913589478
#       floats: 0.8144276142120361
#       floats: 0.9819604158401489
#       floats: 0.8637775182723999
#       floats: 0.0
#       floats: 0.40124091506004333
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9832600951194763
#       floats: 0.0
#       floats: 0.11596538126468658
#       floats: 0.0
#       floats: 0.6105228662490845
#       floats: 0.19199571013450623
#       floats: 0.5458415150642395
#       floats: 0.0
#       floats: 0.46213191747665405
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.27506905794143677
#       floats: 0.2297997772693634
#       floats: 0.24141812324523926
#       floats: 0.8691922426223755
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3063282072544098
#       floats: 0.0
#       floats: 0.6923508048057556
#       floats: 0.5093193054199219
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.18972301483154297
#       floats: 0.9111538529396057
#       floats: 0.8100393414497375
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.831330418586731
#       floats: 0.37640002369880676
#       floats: 0.4410950541496277
#       floats: 0.4813683331012726
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.44310232996940613
#       floats: 0.0
#       floats: 0.0
#       floats: 0.011135866865515709
#       floats: 0.18100497126579285
#       floats: 0.9818531274795532
#       floats: 0.0
#       floats: 0.7211282849311829
#       floats: 0.5839930772781372
#       floats: 0.0
#       floats: 0.45451751351356506
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.20088620483875275
#       floats: 0.8552647233009338
#       floats: 0.35666048526763916
#       floats: 0.0
#       floats: 0.6676839590072632
#       floats: 0.632952094078064
#       floats: 0.0
#       floats: 0.0697183758020401
#       floats: 0.0
#       floats: 0.12709178030490875
#       floats: 0.0
#       floats: 0.13019683957099915
#       floats: 0.0
#       floats: 0.0
#       floats: 0.2977038025856018
#       floats: 0.5717347264289856
#       floats: 0.585908830165863
#       floats: 0.8709859848022461
#       floats: 0.7424392104148865
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9038150310516357
#       floats: 0.3065956234931946
#       floats: 0.0
#       floats: 0.09186119586229324
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8648826479911804
#       floats: 0.6603695154190063
#       floats: 0.6130615472793579
#       floats: 0.0
#       floats: 0.15429191291332245
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5575013160705566
#       floats: 0.0
#       floats: 0.0
#       floats: 0.25590601563453674
#       floats: 0.0
#       floats: 0.0
#       floats: 0.990951657295227
#       floats: 0.0
#       floats: 0.5397096276283264
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9891954660415649
#       floats: 0.9808390140533447
#       floats: 0.21425874531269073
#       floats: 0.006641358602792025
#       floats: 0.49030300974845886
#       floats: 0.6211612820625305
#       floats: 0.009772321209311485
#       floats: 0.6557744145393372
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.4699003994464874
#       floats: 0.973629355430603
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9929253458976746
#       floats: 0.8771036267280579
#       floats: 0.9965102076530457
#       floats: 0.6171948909759521
#       floats: 0.9965704679489136
#       floats: 0.0
#       floats: 0.7582302093505859
#       floats: 0.0
#       floats: 0.0
#       floats: 0.12741665542125702
#       floats: 0.0
#       floats: 0.0
#       floats: 0.42675623297691345
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6743336319923401
#       floats: 0.0
#       floats: 0.6255460977554321
#       floats: 0.5381758809089661
#       floats: 0.23464445769786835
#       floats: 0.6762495636940002
#       floats: 0.0
#       floats: 0.49223941564559937
#       floats: 0.4986322820186615
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.37074029445648193
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5875247120857239
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6797581911087036
#       floats: 0.4240991473197937
#       floats: 0.0
#       floats: 0.0
#       floats: 0.42138686776161194
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3821412920951843
#       floats: 0.9735934734344482
#       floats: 0.0
#       floats: 0.1123122125864029
#       floats: 0.6824139952659607
#       floats: 0.11491964012384415
#       floats: 0.9472307562828064
#       floats: 0.5103407502174377
#       floats: 0.031344570219516754
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8230188488960266
#       floats: 0.8173806667327881
#       floats: 0.5712518095970154
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6757538914680481
#       floats: 0.0
#       floats: 0.26410266757011414
#       floats: 0.5363344550132751
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.4797331392765045
#       floats: 0.15367287397384644
#       floats: 0.0
#       floats: 0.034478429704904556
#       floats: 0.0
#       floats: 0.20445452630519867
#       floats: 0.4071854054927826
#       floats: 0.2948018014431
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0729428306221962
#       floats: 0.5390135645866394
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6466522812843323
#       floats: 0.7405945658683777
#       floats: 0.5534490942955017
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6911420822143555
#       floats: 0.0
#       floats: 0.0
#       floats: 0.06209564954042435
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.317048043012619
#       floats: 0.15269909799098969
#       floats: 0.0
#       floats: 0.0
#       floats: 0.506401002407074
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8994106650352478
#       floats: 0.0
#       floats: 0.7585435509681702
#       floats: 0.40634241700172424
#       floats: 0.5270958542823792
#       floats: 0.8892711400985718
#       floats: 0.8417943716049194
#       floats: 0.9197563529014587
#       floats: 0.0
#       floats: 0.7294166088104248
#       floats: 0.0
#       floats: 0.7220287919044495
#       floats: 0.6048742532730103
#       floats: 0.851349413394928
#       floats: 0.4823596775531769
#       floats: 0.44132697582244873
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.41288140416145325
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.7995268702507019
#       floats: 0.311246782541275
#       floats: 0.7531193494796753
#       floats: 0.5832736492156982
#       floats: 0.09042485058307648
#       floats: 0.5946494936943054
#       floats: 0.5567567348480225
#       floats: 0.5185195207595825
#       floats: 0.0
#       floats: 0.0
#       floats: 0.2595858871936798
#       floats: 0.815179705619812
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5338795781135559
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.828030526638031
#       floats: 0.6095861196517944
#       floats: 0.5967234969139099
#       floats: 0.0
#       floats: 0.4646008014678955
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.961502194404602
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8883711695671082
#       floats: 0.0
#       floats: 0.39926058053970337
#       floats: 0.3451806902885437
#       floats: 0.24329733848571777
#       floats: 0.4182245433330536
#       floats: 0.16092552244663239
#       floats: 0.5687038898468018
#       floats: 0.11387648433446884
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5132331252098083
#       floats: 0.4069608449935913
#       floats: 0.0
#       floats: 0.0
#       floats: 0.5485364198684692
#       floats: 0.7340351939201355
#       floats: 0.0
#       floats: 0.0
#       floats: 0.2039063572883606
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6707278490066528
#       floats: 0.5704056620597839
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6003950834274292
#       floats: 0.8668661713600159
#       floats: 0.7832150459289551
#       floats: 0.36671650409698486
#       floats: 0.3807682693004608
#       floats: 0.0
#       floats: 0.0
#       floats: 0.6989949941635132
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3134237229824066
#       floats: 0.4644259512424469
#       floats: 0.0
#       floats: 0.8819057941436768
#       floats: 0.7876437306404114
#       floats: 0.5402902960777283
#       floats: 0.21393027901649475
#       floats: 0.2036617547273636
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8784627914428711
#       floats: 0.41288140416145325
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.009423797018826008
#       floats: 0.4077187776565552
#       floats: 0.019477996975183487
#       floats: 0.0
#       floats: 0.5293437838554382
#       floats: 0.0
#       floats: 0.0
#       floats: 0.8784860372543335
#       floats: 0.8105757236480713
#       floats: 0.2294211983680725
#       floats: 0.0
#       floats: 0.0
#       floats: 0.3016194701194763
#       floats: 0.0
#       floats: 0.6012352108955383
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.05002232640981674
#       floats: 0.2200850248336792
#       floats: 0.8828514218330383
#       floats: 0.0
#       floats: 0.0
#       floats: 0.12521541118621826
#       floats: 0.8438094854354858
#       floats: 0.3675597906112671
#       floats: 0.9108726382255554
#       floats: 0.0
#       floats: 0.0
#       floats: 0.21805943548679352
#       floats: 0.0
#       floats: 0.34035468101501465
#       floats: 0.8165000677108765
#       floats: 0.0
#       floats: 0.0
#       floats: 0.7906619310379028
#       floats: 0.720718502998352
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.964387059211731
#       floats: 0.829670250415802
#       floats: 0.21319398283958435
#       floats: 0.0
#       floats: 0.4955972731113434
#       floats: 0.9785073399543762
#       floats: 0.0
#       floats: 0.26805537939071655
#       floats: 0.0
#       floats: 0.0
#       floats: 0.10131284594535828
#       floats: 0.0
#       floats: 0.0
#       floats: 0.4059838056564331
#       floats: 0.46679922938346863
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       type: FLOATS
#     }
#     attribute {
#       name: "post_transform"
#       s: "LOGISTIC"
#       type: STRING
#     }
#     domain: "ai.onnx.ml"
#   }
#   node {
#     input: "probability_tensor"
#     output: "probabilities"
#     name: "ZipMap"
#     op_type: "ZipMap"
#     attribute {
#       name: "classlabels_int64s"
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     doc_string: ""
#     domain: "ai.onnx.ml"
#   }
#   node {
#     input: "label_tensor"
#     output: "label"
#     name: "Cast"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 7
#       type: INT
#     }
#     doc_string: ""
#     domain: ""
#   }
#   name: "e2fc102756cb423a8944e429a989aadd"
#   input {
#     name: "input"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 10000
#           }
#           dim {
#             dim_value: 28
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "label"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "probabilities"
#     type {
#       sequence_type {
#         elem_type {
#           map_type {
#             key_type: 7
#             value_type {
#               tensor_type {
#                 elem_type: 1
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 9
# }
# opset_import {
#   domain: "ai.onnx.ml"
#   version: 1
# }

# %%
with open("lgbm_onnx.onnx", "wb") as f:
    f.write(onnx_ml_model.SerializeToString())

# %%
# Use Hummingbird to convert the ONNXML model to ONNX.
onnx_model = convert(onnx_ml_model, "onnx", X)

# %% [markdown]
# Lets do a test to see how fast does the code take to run.
# At the time this workbook I got:
# > Average 1.95 Min=1.92 Max=1.97

# %%
speed("onnx_model.predict(X)")
# Out:
# Average 1.77 Min=1.68 Max=1.85
# 1.769425600799997

# %% [markdown]
# ### Reload the serialized ONNX file
# We had serialized the model and we can load it again. And run it in the inference session.
# Lets create the interfese session

# %%
sess = ort.InferenceSession("lgbm_onnx.onnx")

print("input name='{}' and shape={}".format(
    sess.get_inputs()[0].name, sess.get_inputs()[0].shape))
print("output name='{}' and shape={}".format(
    sess.get_outputs()[0].name, sess.get_outputs()[0].shape))
# Out:
# input name='input' and shape=[10000, 28]
# output name='label' and shape=[1]

# %%
input_name = sess.get_inputs()[0].name
label_name = sess.get_outputs()[0].name

pred_onx = sess.run([label_name], {input_name: X.astype(np.float32)})[0]

# %% [markdown]
# ### Speed Tests for the Inference session.

# %%
sess.run([label_name], {input_name: X.astype(np.float32)})[0]
# Out:
# array([1, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
speed("model.predict(X)")
# Out:
# Average 0.0536 Min=0.0533 Max=0.0538
# 0.05355548790000171

# %% [markdown]
# ### Lets move over to hummingbird library with the default GEMM implementation.
#
# #### GEneric Matrix Multiplication (GEMM) Algorithm
# The evaluation of a tree is done as a series ofthree GEneric Matrix Multiplication (GEMM) operations interleaved by two element-wise logical operations.
#
# Given a tree, we create fivetensors which collectively capture the tree structure:A,B,C,D,andE.
# 1. **A** captures the relationship between input features and internal nodes.
# 2. **B** is set to the threshold value of each internal node.
# 3. For any leaf node and internal node pair,**C** captures whether the internal node is a parent of that internal node, and if so, whether it is in the left or right sub-tree.
# 4. **D** captures the count of the internal nodes in the path from a leaf node to the tree root, for which the internal node is the left child of its parent.
# 5. Finally,**E** captures the mapping between leaf nodes and the class labels.

# %%
# Use Hummingbird to convert the ONNXML model to ONNX.
onnx_model = convert(onnx_ml_model, "pytorch", X, extra_config={"tree_implementation":"gemm"})

#Speed test with GPU
speed("onnx_model.to('cuda');onnx_model.predict(X)")

#Speed test with CPU only
speed("onnx_model.predict(X)")
# Out:
# Average 0.557 Min=0.00467 Max=1.11
# Average 0.00458 Min=0.00457 Max=0.0046
# 0.00458139729999516

# %% [markdown]
# At the time of the run, GPU performance averaged at 0.62 seconds while CPU averaged. This is expected as there is a huge overhead to transfer data to and from the GPU.
#
# > Average 0.62 Min=0.00469 Max=1.23
#
# > Average 0.00461 Min=0.00458 Max=0.00464

# %% [markdown]
# ### Tree Traversal Algorithm
# Lets try an another algorithm which improves on the logic of GEMM. In the GEMM strategy, there was a high-degree of computational redundancy by evaluating all internal nodes and leaf nodes when only a few of them actually need to be evaluated.  The Tree traversal the algorithm tries to reduce the computational redundancy by mimicking the typical tree traversal but implemented using tensor operations

# %%
# Use Hummingbird to convert the ONNXML model to ONNX.
onnx_model = convert(onnx_ml_model, "pytorch", X, extra_config={"tree_implementation":"tree_trav"})

#Speed test with GPU
speed("onnx_model.to('cuda');onnx_model.predict(X)")

#Speed test with CPU only
speed("onnx_model.predict(X)")
# Out:
# Average 0.0075 Min=0.00546 Max=0.00954
# Average 0.00548 Min=0.00537 Max=0.00558
# 0.0054752662999987935

# %% [markdown]
# At the time of the run, GPU performance averaged at 0.007 seconds while CPU averaged 0.00542 seconds. The GPU run has been significantly improved as compared to GEMM algorithm
#
# > Average 0.007 Min=0.00544 Max=0.00855
#
# > Average 0.00542 Min=0.00536 Max=0.00548

# %% [markdown]
# ### Perfect Tree Traversal Algorithm
#
# Similar to the tree traversal algorithm,this  strategy  also  mimics  the  tree  traversal. However,  here  weassume the tree is a *perfect binary tree*. In a perfect binary tree, all internal nodes have exactly two children and all leaf nodes are at the same depth level.

# %%
# Use Hummingbird to convert the ONNXML model to ONNX.
onnx_model = convert(onnx_ml_model, "pytorch", X, extra_config={"tree_implementation":"perf_tree_trav"})
speed("onnx_model.to('cuda');onnx_model.predict(X)")
speed("onnx_model.predict(X)")
# Out:
# Average 0.00774 Min=0.00472 Max=0.0108
# Average 0.00447 Min=0.00441 Max=0.00453
# 0.0044690769999988335

# %% [markdown]
# At the time of the run, GPU performance averaged at 0.00785 seconds while CPU averaged 0.00451 seconds about 16% reduction in inference time.

# %%
model.booster_.save_model('lgbm_Classifier.txt')

# %%
#lets load the saved model in Treelite

trl_model = treelite.Model.load('lgbm_Classifier.txt', model_format='lightgbm')
# Out:
# [07:16:13] /workspace/src/frontend/lightgbm.cc:544: model.num_tree = 100

# %%
toolchain = 'gcc'
trl_model.export_lib(toolchain=toolchain, libpath='./lgbm_numpy.so', verbose=True)
# Out:
# [07:16:13] /workspace/src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [07:16:13] /workspace/src/compiler/ast/split.cc:24: Parallel compilation disabled; all member trees will be dumped to a single source file. This may increase compilation time and memory usage.
# [07:16:14] /workspace/src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [07:16:14] /workspace/src/c_api/c_api.cc:291: Writing file main.c...
# [07:16:14] /workspace/src/c_api/c_api.cc:291: Writing file recipe.json...
# [07:16:14] /workspace/src/c_api/c_api.cc:291: Writing file header.h...
# [07:16:14] /root/.local/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [07:16:14] /root/.local/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmph4s2qbnc into object files (*.o)...
# [07:16:25] /root/.local/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmph4s2qbnc/predictor.so...
# [07:16:25] /root/.local/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 11.58 seconds

# %%
predictor = treelite_runtime.Predictor('./lgbm_numpy.so', verbose=True)
batch = treelite_runtime.Batch.from_npy2d(X)
out_pred = predictor.predict(batch)
# Out:
# [07:17:44] /root/.local/lib/python3.7/site-packages/treelite_runtime/predictor.py:309: Dynamic shared library /kaggle/working/lgbm_numpy.so has been successfully loaded into memory

# %%
speed('predictor.predict(batch)')
# Out:
# Average 0.000782 Min=0.000253 Max=0.00131
# 0.0007824436000021251

# %% [markdown]
# At the time of the run, CPU averaged 0.000472 seconds compare this with Hummingbird's best case for CPU that was 0.00451 seconds almost **10X reduction** because we were able to compile the model.
#
# The base lightGBM model was 0.05 seconds, which is **100X slower** than a compiled model.
#
# Note: The first batch run will be slower as compared to the subsequent ones.

# %% [markdown]
# # **Lets try the Boston Dataset**

# %%
from sklearn.datasets import load_boston
X, y = load_boston(return_X_y=True)
print(f'dimensions of X = {X.shape}')
print(f'dimensions of y = {y.shape}')
# Out:
# dimensions of X = (506, 13)
# dimensions of y = (506,)

# %%
import xgboost
dtrain = xgboost.DMatrix(X, label=y)
params = {'max_depth':3, 'eta':1, 'objective':'reg:squarederror', 'eval_metric':'rmse'}
bst = xgboost.train(params, dtrain, 20, [(dtrain, 'train')])
# Out:
# [0]	train-rmse:3.89050
# [1]	train-rmse:3.38204
# [2]	train-rmse:3.10513
# [3]	train-rmse:2.84322
# [4]	train-rmse:2.60580
# [5]	train-rmse:2.45425
# [6]	train-rmse:2.29526
# [7]	train-rmse:2.17920
# [8]	train-rmse:2.09359
# [9]	train-rmse:1.96872
# [10]	train-rmse:1.93416
# [11]	train-rmse:1.83528
# [12]	train-rmse:1.78750
# [13]	train-rmse:1.71018
# [14]	train-rmse:1.64747
# [15]	train-rmse:1.57359
# [16]	train-rmse:1.49626
# [17]	train-rmse:1.43896
# [18]	train-rmse:1.37123
# [19]	train-rmse:1.30187

# %%
model = treelite.Model.from_xgboost(bst)

# %%
toolchain = 'gcc'

# %%
model.export_lib(toolchain=toolchain, libpath='./boston.so', verbose=True)
# Out:
# [07:16:26] /workspace/src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [07:16:26] /workspace/src/compiler/ast/split.cc:24: Parallel compilation disabled; all member trees will be dumped to a single source file. This may increase compilation time and memory usage.
# [07:16:26] /workspace/src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [07:16:26] /workspace/src/c_api/c_api.cc:291: Writing file main.c...
# [07:16:26] /workspace/src/c_api/c_api.cc:291: Writing file recipe.json...
# [07:16:26] /workspace/src/c_api/c_api.cc:291: Writing file header.h...
# [07:16:26] /root/.local/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmpsbfbm3ts into object files (*.o)...
# [07:16:26] /root/.local/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmpsbfbm3ts/predictor.so...
# [07:16:26] /root/.local/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 0.27 seconds

# %%
import treelite_runtime     # runtime module
predictor = treelite_runtime.Predictor('./boston.so', verbose=True)
# Out:
# [07:16:26] /root/.local/lib/python3.7/site-packages/treelite_runtime/predictor.py:309: Dynamic shared library /kaggle/working/boston.so has been successfully loaded into memory

# %%
batch = treelite_runtime.Batch.from_npy2d(X, rbegin=1, rend=500)

# %%
out_pred = predictor.predict(batch)
print(out_pred)
# Out:
# [20.186111  34.48005   37.285862  33.69207   28.283451  21.867765
#  23.253294  17.29624   20.040396  16.950441  19.283855  21.816017
#  20.342304  17.260868  20.342304  21.587475  18.442554  20.078833
#  16.137157  13.929457  17.316753  17.636827  13.304058  15.001148
#  13.821014  15.20974   14.832266  16.640896  20.459078  12.8455925
#  17.52793   14.709333  14.155782  13.9590435 22.456371  20.259691
#  22.808983  23.44831   30.543415  35.029102  28.100641  22.866552
#  23.63423   22.805105  20.411028  20.411028  17.836796  14.136219
#  19.081121  18.90171   20.825583  24.688742  23.183697  18.225296
#  36.0195    23.34298   29.869055  23.83893   20.78524   18.64497
#  17.47499   22.292019  24.869267  31.435106  23.953838  17.844997
#  21.295427  18.80207   20.94234   23.24848   20.191523  23.353277
#  23.414724  23.820236  21.87087   21.023169  21.270945  20.442343
#  21.627295  25.187714  24.482016  22.956995  21.826084  22.557856
#  24.683212  19.681183  23.851255  22.215725  30.038284  22.432909
#  22.771053  24.742664  26.603731  20.451595  27.10851   23.301662
#  37.94917   43.98786   33.351986  26.285599  26.285599  16.96351
#  19.64142   19.895227  21.465393  19.489714  20.251236  22.021214
#  19.216208  20.145144  22.776731  18.300919  18.925642  19.796833
#  17.164368  21.085485  19.355755  19.3945    19.537802  22.993055
#  20.087858  21.170137  16.171148  20.13379   21.333956  15.529733
#  15.371907  18.933416  14.558287  19.574831  21.261833  21.887232
#  19.405157  13.8728695 16.485102  16.030605  18.933416  13.214797
#  16.286427  14.3939495 14.63555   14.796241  15.776361  12.981915
#  14.048007  17.818012  12.842368  15.683957  14.837037  19.690691
#  19.498055  17.299314  20.321922  17.885159  14.553416  12.209076
#  40.792538  25.21947   23.115696  25.21947   48.71665   48.547844
#  50.057438  21.502619  22.73823   48.230343  23.376484  23.284328
#  23.099213  20.322485  20.447735  20.055355  24.64898   23.78228
#  29.597574  23.737942  24.645037  27.63866   39.683674  41.58735
#  33.8905    41.721786  30.330925  26.808662  29.677408  47.585506
#  30.977417  28.40052   35.158245  36.933037  30.763935  35.727184
#  30.376642  30.084871  49.13559   34.076168  29.589077  33.4212
#  34.826435  33.503788  22.913746  41.87505   49.85763   49.85763
#  24.248253  23.941557  22.141521  24.922163  19.99407   21.231281
#  18.820366  23.117342  26.703777  22.470764  27.725262  22.378366
#  29.861193  23.305115  22.239662  29.42161   19.326307  24.062372
#  27.710787  44.710365  48.508423  39.290123  32.08745   47.51865
#  31.446795  23.779064  33.623596  43.522247  46.722412  29.075619
#  23.779064  26.097456  32.34012   24.480907  26.352457  21.940342
#  19.99848   21.378088  24.066328  18.69387   19.079306  23.83893
#  19.705124  25.580238  26.206005  24.638166  23.724072  30.30406
#  41.810486  21.877062  21.48198   43.505665  50.330334  36.298397
#  31.8862    36.30908   43.63158   47.78934   29.233215  35.2593
#  23.40631   31.184696  49.581444  46.339046  22.03441   20.664835
#  23.63423   23.975979  36.213093  32.67393   32.320843  31.025257
#  32.363686  28.17288   34.809017  44.244873  34.932217  47.504734
#  49.086285  32.17664   23.17423   19.74361   22.62805   21.922352
#  24.070082  28.496645  36.280575  30.189129  24.524658  21.301456
#  27.838308  26.656572  19.52156   23.013317  29.26294   25.042173
#  24.995125  24.480907  34.371616  35.65839   27.821829  31.522549
#  28.122992  23.915253  20.546013  17.3386    24.372726  19.355755
#  23.11843   23.621557  18.346642  17.433643  18.346642  21.508694
#  21.149525  23.37495   23.015781  23.015781  17.025406  24.080648
#  24.745556  23.72148   20.498278  19.320642  23.555098  20.919636
#  18.400053  19.731256  21.551394  21.055832  21.9479    18.019001
#  18.019001  21.9479    19.22026   21.737764  33.016663  19.552412
#  24.289427  27.948997  19.616114  16.940603  22.413116  25.472168
#  25.875895  22.059067  24.16746   19.126892  29.816856  19.039953
#  19.182428  15.119478  20.239367  22.039244  23.089954  25.053194
#  18.839611  21.337337  18.789192  21.321215  27.873646  20.95264
#  25.281868  49.920216  51.2166    49.85162   49.686485  48.675232
#  13.033164  13.619732  15.739247  14.289633  10.859746  11.203178
#   9.886494   8.944397  10.483015  10.916585  11.847817  10.501775
#   7.310889   9.125214   8.529136   9.727659  10.916585  14.796431
#  20.792507  10.916585  16.958797  11.2914715 12.522345  13.10463
#   9.673834   4.9085765  7.6666265  7.4230103 10.145614  11.955862
#  10.5085945  7.489748   5.5339766 13.660528  29.04538   17.227413
#  26.07719   15.308844  18.200298  16.671198  17.421926   7.1634684
#   8.448672   8.874819   9.463036   7.2638245  7.2249637 16.121586
#  14.936738  20.032572  11.599073  14.210915   7.7495604 10.953298
#   9.521269  11.699144  11.812691  14.586939  16.489967  14.356924
#  15.213409  10.386755  14.1347885 11.229695   9.408341   7.5830135
#  10.637845   9.272683  16.747065  16.733637  15.436521  11.668295
#  11.3657465 13.313945  13.1098175 13.249365  13.696817  12.67778
#  16.270464  16.83599   15.461304  14.009279  14.088921  15.412825
#  13.14043   13.936851  18.940956  17.815998  18.900076  18.940956
#  19.839598  20.589935  19.53709   19.379866  16.568521  19.12786
#  19.578682  21.731167  20.335876  21.444654  28.034761  15.474816
#  14.45421   16.543879  12.519113  14.650859  20.917515  20.589935
#  23.750282  26.883232  20.92252   20.631525  20.549055  19.7987
#  22.537422  14.479151   9.189997   9.189997  13.398946  20.390783
#  20.257975  22.47821   22.853865  17.794458  18.394258  20.688602
#  19.53476  ]

# %%
dmX = xgboost.DMatrix(X)
speed('bst.predict(dmX)')
# Out:
# Average 0.000133 Min=5.66e-05 Max=0.00021
# 0.00013311490000091907

# %%
speed('out_pred = predictor.predict(batch)')
# Out:
# Average 0.000255 Min=0.000135 Max=0.000374
# 0.00025455820000388487
